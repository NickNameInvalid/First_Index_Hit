# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
budget_list = ['500', '1000', '2000', '3000', '4000', '6000', '8000', '12000', '15000', '18000', '25000', '35000', '50000']
vanilla_hit_ratio_list = [0.7351540458187558, 0.7861640898318457, 0.8299853289696388, 0.8518000225708123, 0.8656697889628668, \
                          0.8788060038370346, 0.8868299289019248, 0.8948425685588502, 0.8981830493172294, 0.9000451416318666, \
                          0.9025392167926838, 0.9044013091073215, 0.9055637061279733]
vanilla_prior_hit_ratio_list = [0.7116916826543266, 0.7466764473535685, 0.7785464394537844, 0.8442726554564902, 0.8563480419817142, \
                                0.8710754993792988, 0.8782191626227246, 0.8926419140051879, 0.8955196930368997, 0.8970996501523496, \
                                0.9008689764134941, 0.9031373434149611, 0.9040966030921986]

only_pair_hit_ratio_list = [0.6931159011398276, 0.7554113531204132, 0.8101230109468398, 0.837038708949325, 0.8540006771244737, \
                            0.8706805101004342, 0.880984087574761, 0.8910393860738031, 0.894842568558849, 0.8976187789188538, \
                            0.9010495429409741, 0.9034533348380508, 0.9044690215551257]
only_pair_prior_hit_ratio_list = [0.6934770341947866, 0.7455140503329157, 0.7895384268141258, 0.8406838957228256, 0.8553549260805725, \
                                  0.8707933641801109, 0.8841327163976944, 0.8922243539103897, 0.896986796072674, 0.8989843132829215, \
                                  0.9021329421058536, 0.9036903284053683, 0.9044690215551255]

complete_single_hit_ratio_list = [0.7995937253131704, 0.8509084753413831, 0.8945265771357612, 0.9164992664484801, 0.9303464620245998, \
                                  0.9470714366324322, 0.9575442952262697, 0.9681412933077526, 0.9728134522062957, 0.9756348041981697, \
                                  0.9790429974043542, 0.9815483579731393, 0.9829138923372064]
complete_single_prior_hit_ratio_list = [0.7565173231012292, 0.7915020878004712, 0.823101230109466, 0.9039724636045553, 0.9160929917616492, \
                                        0.9345333483805408, 0.9446337885114515, 0.9639656923597768, 0.9681977203475882, 0.9708159349960476, \
                                        0.9761087913328046, 0.9791897077079312, 0.9803972463604542]

complete_single_only_pair_hit_ratio_list = [0.7578828574652992, 0.8203701613813327, 0.8747206861527996, 0.9018508069066671, 0.9188014896738484, \
                                            0.9390587969755063, 0.9517887371628453, 0.9643945378625419, 0.9695293984877521, 0.9735131475002798, \
                                            0.9779370274235395, 0.9810066583906982, 0.9822254824511881]
complete_single_only_pair_prior_hit_ratio_list = [0.7383026746416885, 0.7903396907798178, 0.8340932174698081, 0.9003837038708907, 0.9150998758605077, \
                                                  0.9342512131813527, 0.952657713576344, 0.9635594176729461, 0.9703870894932831, 0.9736485723958904, \
                                                  0.9783433021103685, 0.9808712334950884, 0.9821577700033833]

complete_single_half_prior_hit_ratio_list = [0.8282925177745155, 0.8718654779370261, 0.9102245796185511, 0.9295564834668751, 0.941789865703642, \
                                             0.9564270398374878, 0.9642139713350615, 0.9727570251664576, 0.9761990745965453, 0.9785577248617525, \
                                             0.981232366550049, 0.9827558966256612, 0.9837264417108659]

complete_single_only_pair_half_prior_hit_ratio_list = [0.7773953278410997, 0.8368919986457488, ]

# %%
x = range(len(budget_list))
x = [i + 2 for i in x]
plt.figure(figsize=(18,12))
plt.plot(x, vanilla_hit_ratio_list, color='red', label = 'vanilla', marker = 'o')
plt.plot(x, vanilla_prior_hit_ratio_list, linestyle='dashed', color='red', label = 'vanilla prior', marker = 'o')
plt.plot(x, only_pair_hit_ratio_list, color='orange', label = 'only pair', marker = 'o')
plt.plot(x, only_pair_prior_hit_ratio_list, linestyle='dashed', color='orange', label = 'only pair prior', marker = 'o')
plt.plot(x, complete_single_hit_ratio_list, color='green', label = 'complete single', marker = 'o')
plt.plot(x, complete_single_prior_hit_ratio_list, linestyle='dashed', color='green', label = 'complete single prior', marker = 'o')
plt.plot(x, complete_single_only_pair_hit_ratio_list, color='blue', label = 'only pair complete single', marker = 'o')
plt.plot(x, complete_single_only_pair_prior_hit_ratio_list, linestyle='dashed', color='blue', label = 'only pair complete single prior', marker = 'o')
plt.plot(x, complete_single_half_prior_hit_ratio_list, color='purple', label = 'half prior half evenly', marker = ">")
plt.plot(x, complete_single_only_pair_half_prior_hit_ratio_list, color='black', label = 'only pair half prior half evenly', marker = ">")


plt.xticks([i - 0.02 for i in x], budget_list, fontsize = 20)

plt.ylim(0.65, 0.99)
plt.yticks(fontsize = 20)

plt.legend(loc = 'lower right', fontsize = 24)
plt.title(u"Hit Ratio of Two-Layer Index Structure", fontsize = 24)
plt.xlabel(u"Budget", fontsize = 24)
plt.ylabel(u"Hit Ratio", fontsize = 24)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
